# %% [markdown]
# # Setup

# %%
# !pip install opendatasets
# !pip install pycuber
# Out:
# Requirement already satisfied: opendatasets in /opt/conda/lib/python3.12/site-packages (0.1.22)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (from opendatasets) (4.67.1)
# Requirement already satisfied: kaggle in /opt/conda/lib/python3.12/site-packages (from opendatasets) (2.0.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.12/site-packages (from opendatasets) (8.2.1)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.12/site-packages (from kaggle->opendatasets) (6.2.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.15 in /opt/conda/lib/python3.12/site-packages (from kaggle->opendatasets) (0.1.16)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from kaggle->opendatasets) (25.0)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.12/site-packages (from kaggle->opendatasets) (5.28.3)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.12/site-packages (from kaggle->opendatasets) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /opt/conda/lib/python3.12/site-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from kaggle->opendatasets) (2.32.4)
# Requirement already satisfied: urllib3>=1.15.1 in /opt/conda/lib/python3.12/site-packages (from kaggle->opendatasets) (2.5.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.12/site-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil->kaggle->opendatasets) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in /opt/conda/lib/python3.12/site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->kaggle->opendatasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->kaggle->opendatasets) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->kaggle->opendatasets) (2025.7.9)
# Requirement already satisfied: pycuber in /opt/conda/lib/python3.12/site-packages (0.2.2)

# %%
import opendatasets as od
import pandas

od.download("https://www.kaggle.com/datasets/antbob/rubiks-cube-cfop-solutions")

# %%
# !mv rubiks-cube-cfop-solutions/dataset cfop-dataset
# !rm -r rubiks-cube-cfop-solutions
# Out:
# mv: cannot stat 'rubiks-cube-cfop-solutions/dataset': No such file or directory
