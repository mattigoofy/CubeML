# %% [markdown]
# # Setup

# %%
# !pip install opendatasets
# !pip install pycuber
# Out:
# ...
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# ...
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# ...
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [opendatasets]━━━ 13/15 [kaggle]
# ...

# %%
import opendatasets as od
import pandas

od.download("https://www.kaggle.com/datasets/antbob/rubiks-cube-cfop-solutions")

# %%
# !mv rubiks-cube-cfop-solutions/dataset cfop-dataset
# !rm -r rubiks-cube-cfop-solutions
# Out:
# mv: cannot stat 'rubiks-cube-cfop-solutions/dataset': No such file or directory
