# %% [markdown]
# # Setup

# %%
# !pip install opendatasets
# !pip install pycuber
# Out:
# Requirement already satisfied: opendatasets in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (0.1.22)
# Requirement already satisfied: tqdm in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from opendatasets) (4.67.3)
# Requirement already satisfied: kaggle in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from opendatasets) (2.0.1)
# Requirement already satisfied: click in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from opendatasets) (8.3.2)
# Requirement already satisfied: colorama in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from click->opendatasets) (0.4.6)
# Requirement already satisfied: bleach in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from kaggle->opendatasets) (6.3.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.17 in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from kaggle->opendatasets) (0.1.17)
# Requirement already satisfied: packaging in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from kaggle->opendatasets) (26.0)
# Requirement already satisfied: protobuf in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from kaggle->opendatasets) (7.34.1)
# Requirement already satisfied: python-dateutil in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from kaggle->opendatasets) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: requests in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from kaggle->opendatasets) (2.33.1)
# Requirement already satisfied: urllib3>=1.15.1 in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from kaggle->opendatasets) (2.6.3)
# Requirement already satisfied: webencodings in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: six>=1.5 in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from python-dateutil->kaggle->opendatasets) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from requests->kaggle->opendatasets) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from requests->kaggle->opendatasets) (3.11)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (from requests->kaggle->opendatasets) (2026.2.25)
# Requirement already satisfied: pycuber in c:\Nerdmap\Machine Learning\.venv\Lib\site-packages (0.2.2)

# %%
import opendatasets as od
import pandas

od.download("https://www.kaggle.com/datasets/antbob/rubiks-cube-cfop-solutions")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import opendatasets as od
#       2 import pandas
#       3
#       4 od.download("https://www.kaggle.com/datasets/antbob/rubiks-cube-cfop-solutions")
#
# File c:\Nerdmap\Machine Learning\.venv\Lib\site-packages\opendatasets\__init__.py:2
#       1 import importlib
# ----> 2 from opendatasets.utils.network import download_url, is_url
#       3 from opendatasets.utils.googledrive import is_google_drive_url, download_google_drive
#       4 import os
#
# File c:\Nerdmap\Machine Learning\.venv\Lib\site-packages\opendatasets\utils\__init__.py:1
# ----> 1 from opendatasets.utils.network import download_url
#       3 GITHUB_RAW_BASE_URL = 'https://raw.githubusercontent.com/JovianML/opendatasets/master/data/'
#       6 def download_raw_files(dataset_id, data_dir, dry_run, files):
#
# File c:\Nerdmap\Machine Learning\.venv\Lib\site-packages\opendatasets\utils\network.py:2
#       1 import os
# ----> 2 import cgi
#       3 import re
#       4 from tqdm import tqdm
#
# ModuleNotFoundError: No module named 'cgi'

# %%
# !mv rubiks-cube-cfop-solutions/dataset cfop-dataset
# !rm -r rubiks-cube-cfop-solutions
# Out:
# mv: cannot stat 'rubiks-cube-cfop-solutions/dataset': No such file or directory
